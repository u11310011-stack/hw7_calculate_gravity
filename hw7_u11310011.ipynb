# %%
import numpy as np

# %%
lon = 12.1878 ; lat = 48.1995 ; ele = 487.9 ; Go = 980717.39

# %%
Ge = 978031.85

# %%
np.pi
# Out:
# 3.141592653589793

# %%
fac = np.pi/180.0

# %%
print(np.sin(90*fac))
# Out:
# 1.0

# %%
print(np.sin(0))
# Out:
# 0.0

# %%
Gt = Ge * (1 + 0.00578895*np.sin(lat*fac)**2+ 0.000023462*np.sin(lat*fac)**4 )

# %%
print(f"theoretical gravity : {Gt}")
# Out:
# theoretical gravity : 981185.3324033826
